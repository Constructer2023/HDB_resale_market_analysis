# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from src.DataLoad_ResaleTransactions import load_transactions
from src.InterimAnalysis_ResaleTransactions import (market_snapshot,
                                                    yearly_summary,
                                                    monthly_summary,
                                                    town_summary,
                                                    flat_type_summary,
                                                    add_bands
                                                    )
from src.InterimPlot_ResaleTransactions import (output_path,
                                                _save,
                                                plot_yearly_volume_price,
                                                plot_monthly_volume_price,
                                                plot_town_ranking,
                                                plot_price_distribution,
                                                plot_band_vs_price
                                                )

sns.set_theme(style = 'whitegrid')
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df = load_transactions(path = None)
print(df.shape)
print(df.head())
df.info()
# Out:
# (239265, 17)
#     trx_date  trx_year  trx_month  lease_commence  flat_year  \
# 0 2017-01-01      2017          1            1979         38
# 1 2017-01-01      2017          1            1978         39
# 2 2017-01-01      2017          1            1980         37
# 3 2017-01-01      2017          1            1980         37
# 4 2017-01-01      2017          1            1980         37
#
#    remaining_lease_month flat_type      flat_model        town  \
# 0                    736    2 ROOM        Improved  ANG MO KIO
# 1                    727    3 ROOM  New Generation  ANG MO KIO
# 2                    749    3 ROOM  New Generation  ANG MO KIO
# 3                    745    3 ROOM  New Generation  ANG MO KIO
# 4                    749    3 ROOM  New Generation  ANG MO KIO
#
#          street_name block  storey_lower  storey_midpoint  storey_upper  \
# 0  ANG MO KIO AVE 10   406            10               11            12
# 1   ANG MO KIO AVE 4   108             1                2             3
# 2   ANG MO KIO AVE 5   602             1                2             3
# 3  ANG MO KIO AVE 10   465             4                5             6
# 4   ANG MO KIO AVE 5   601             1                2             3
#
#    price_per_sqm  floor_area_sqm  resale_price
# 0        5272.73           44.00     232000.00
# 1        3731.34           67.00     250000.00
# 2        3910.45           67.00     262000.00
# 3        3897.06           68.00     265000.00
# 4        3955.22           67.00     265000.00
# <class 'pandas.DataFrame'>
# RangeIndex: 239265 entries, 0 to 239264
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   trx_date               239265 non-null  datetime64[us]
#  1   trx_year               239265 non-null  int64
#  2   trx_month              239265 non-null  int64
#  3   lease_commence         239265 non-null  int64
#  4   flat_year              239265 non-null  int64
#  5   remaining_lease_month  239265 non-null  int64
#  6   flat_type              239265 non-null  str
#  7   flat_model             239265 non-null  str
#  8   town                   239265 non-null  str
#  9   street_name            239265 non-null  str
#  10  block                  239265 non-null  str
#  11  storey_lower           239265 non-null  int64
#  12  storey_midpoint        239265 non-null  int64
#  13  storey_upper           239265 non-null  int64
#  14  price_per_sqm          239265 non-null  float64
#  15  floor_area_sqm         239265 non-null  float64
#  16  resale_price           239265 non-null  float64
# dtypes: datetime64[us](1), float64(3), int64(8), str(5)
# memory usage: 31.0 MB

# %%
snap = market_snapshot(df)
snap
# Out:
# {'total_transactions': 239265,
#  'earliest_date': Timestamp('2017-01-01 00:00:00'),
#  'latest_date': Timestamp('2026-09-01 00:00:00'),
#  'mean_price': np.float64(534525.246317096),
#  'median_price': np.float64(503000.0),
#  'mean_pps': np.float64(5589.999744551022),
#  'median_pps': np.float64(5310.0),
#  'mean_area': np.float64(96.68832800451382),
#  'median_area': np.float64(93.0)}
